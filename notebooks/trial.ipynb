# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
import pandas as pd
import joblib
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../data/processed/AUS_weather_features.csv')

# %%
df
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0          13.4     22.9       0.6           44.0          20.0          24.0
# 1           7.4     25.1       0.0           44.0           4.0          22.0
# 2          12.9     25.7       0.0           46.0          19.0          26.0
# 3           9.2     28.0       0.0           24.0          11.0           9.0
# 4          17.5     32.3       1.0           41.0           7.0          20.0
# ...         ...      ...       ...            ...           ...           ...
# 143026      2.8     23.4       0.0           31.0          13.0          11.0
# 143027      3.6     25.3       0.0           22.0          13.0           9.0
# 143028      5.4     26.9       0.0           37.0           9.0           9.0
# 143029      7.8     27.0       0.0           28.0          13.0           7.0
# 143030     14.9     22.6       0.0           39.0          17.0          17.0
#
# ...

# %%
X = df.drop(columns=['RainTomorrow'])
y_class = df['RainTomorrow']

x_train, x_test, y_class_train, y_class_test = train_test_split(
    X, y_class, test_size= 0.2, random_state=6
)

# %%
X.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'windGust_x',
#        'windGust_y', 'wind9am_x', 'wind9am_y', 'wind3pm_x', 'wind3pm_y',
#        'Year', 'Month', 'Day', 'DayOfYear'],
#       dtype='object')

# %% [markdown]
# import joblib
# import pandas as pd
#
# # Load model
# model = joblib.load("model.pkl")
#
# # Ambil 1 sampel data hari ini
# today_data = pd.DataFrame({
#     'MinTemp': [22.4],
#     'MaxTemp': [30.5],
#     'Rainfall': [0.2],
#     'Humidity3pm': [65],
#     'Pressure3pm': [1013],
#     'Temp3pm': [29.1],
#     'RainToday': [0],
#     'WindSpeed3pm': [15],
#     # dst...
# })
#
# # Prediksi biner
# prediction = model.predict(today_data)[0]
#
# # Prediksi probabilitas
# rain_prob = model.predict_proba(today_data)[0][1]  # kolom ke-1 = probabilitas hujan
#
# print(f"Besok kemungkinan hujan: {rain_prob*100:.2f}%")
